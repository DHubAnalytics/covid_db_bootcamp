# %%
from unidecode import unidecode
import pandas as pd
import numpy as np
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap


sns.set(rc={'figure.figsize': (10, 6)})

# %%
df, muta = [pd.read_csv(file_) for file_ in glob.glob(os.path.join('../data/raw/', '*'))]

# %% [markdown]
# ### Missing Values

# %%
df.isna().mean() * 100
# Out:
# GISAID ID                     0.060680
# Unnamed: 1                  100.000000
# Virus name                    0.060680
# FECHA DE COLECCIÓN            0.060680
# FECHA DE SUBIDA A GISAID      0.060680
# PROVINCIA                     0.060680
# CIUDAD                        0.242718
# TIPO                          0.910194
# Genero                        0.060680
# Edad                          0.060680
# Linaje                        0.060680
# Clado                         0.060680
# Mutaciones                    0.060680
# dtype: float64

# %%
muta.isna().mean() * 100
# Out:
# 0I (Alpha, V1) (B.1.1.7)        78.181818
# 20H (Beta, V2) (B.1.351)        80.000000
# 20J (Gamma, V3) (P.1)           78.181818
# 21A (Delta) (B.1.617.2)         83.636364
# 21B (Kappa) (B.1.617.1)         89.090909
# 21K (Omicron) (BA.1)            34.545455
# 21L (Omicron) (BA.2)            43.636364
# 22A & 22B (Omicron) (BA.4&5)    38.181818
# 22C (Omicron) (BA.2.12.1)       40.000000
# 21D (Eta) (B.1.525)             83.636364
# 21F (Iota) (B.1.526)            89.090909
# 21G (Lambda) (C.37)             74.545455
# 21H (Mu) (B.1.621)              83.636364
# dtype: float64

# %% [markdown]
# ### Memory Usage

# %%
(df
 .memory_usage(deep=True)
 .pipe(lambda df_:pd.concat([df_, df.dtypes], axis=1))
 .rename(columns={0:'memory', 1:'dtype'})
)
# Out:
#                           memory    dtype
# Index                        128      NaN
# GISAID ID                 119098   object
# Unnamed: 1                 13184  float64
# Virus name                143752   object
# FECHA DE COLECCIÓN        110114   object
# FECHA DE SUBIDA A GISAID  110381   object
# PROVINCIA                 110907   object
# CIUDAD                    106642   object
# TIPO                      109197   object
# Genero                    102496   object
# Edad                      104054   object
# Linaje                    103418   object
# Clado                      97556   object
# Mutaciones                601525   object

# %% [markdown]
# ### The Data

# %%
df.sample(10).T
# Out:
#                                                                        159   \
# GISAID ID                                                   EPI_ISL_1656147
# Unnamed: 1                                                              NaN
# Virus name                                hCoV-19/Ecuador/USFQ-ECU1067/2021
# FECHA DE COLECCIÓN                                               2021-04-01
# FECHA DE SUBIDA A GISAID                                         2021-04-20
# PROVINCIA                                                           Manabi
# CIUDAD                                                           Portoviejo
# TIPO                                                               Hospital
# Genero                                                               Female
# Edad                                                                unknown
# Linaje                                                                  P.1
# Clado                                                                    GR
# Mutaciones                (NSP10_T12I,NSP14_P443S,Spike_R190S,NSP6_S106d...
#
#                                                                        496   \
# GISAID ID                                                   EPI_ISL_3133387
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-1717/2021
# FECHA DE COLECCIÓN                                               2021-07-14
# FECHA DE SUBIDA A GISAID                                         2021-07-29
# PROVINCIA                                                         Pichincha
# CIUDAD                                                    Coliseo Rumiñahui
# TIPO                                                            Ambulatorio
# Genero                                                               Female
# Edad                                                                unknown
# Linaje                                                              B.1.621
# Clado                                                                     G
# Mutaciones                (NSP13_P419S,Spike_T95I,Spike_D950N,Spike_E484...
#
#                                                                        212   \
# GISAID ID                                                   EPI_ISL_1896696
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-1180/2021
# FECHA DE COLECCIÓN                                               2021-04-23
# FECHA DE SUBIDA A GISAID                                         2021-05-04
# PROVINCIA                                                    Santo Domingo
# CIUDAD                                                       Santo Domingo
# TIPO                                                               Hospital
# Genero                                                               Female
# Edad                                                                unknown
# Linaje                                                              B.1.1.7
# Clado                                                                     G
# Mutaciones                (NSP3_T183I,NSP3_A890D,NSP6_G107del,Spike_T716...
#
#                                                                        429   \
# GISAID ID                                                   EPI_ISL_3062495
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-1639/2021
# FECHA DE COLECCIÓN                                               2021-07-05
# FECHA DE SUBIDA A GISAID                                         2021-07-23
# PROVINCIA                                                         Pichincha
# CIUDAD                                                            SANGOLQUI
# TIPO                                                            Ambulatorio
# Genero                                                                 Male
# Edad                                                                unknown
# Linaje                                                              A.2.5.3
# Clado                                                                     S
# Mutaciones                (N_P365S,Spike_A67V,Spike_G142del,N_M234I,NSP1...
#
#                                                                        323   \
# GISAID ID                                                   EPI_ISL_2484965
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-1427/2021
# FECHA DE COLECCIÓN                                               2021-05-18
# FECHA DE SUBIDA A GISAID                                         2021-06-11
# PROVINCIA                                                           Carchi
# CIUDAD                                                               TULCÁN
# TIPO                                                               Hospital
# Genero                                                                 Male
# Edad                                                                unknown
# Linaje                                                                 C.37
# Clado                                                                    GR
# Mutaciones                (Spike_L249del,Spike_S247del,Spike_G75V,Spike_...
#
#                                                                        1087  \
# GISAID ID                                                  EPI_ISL_10801151
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-2724/2022
# FECHA DE COLECCIÓN                                               2022-01-18
# FECHA DE SUBIDA A GISAID                                         2022-03-08
# PROVINCIA                                                       Tungurahua
# CIUDAD                                                               AMBATO
# TIPO                                                               Hospital
# Genero                                                               Female
# Edad                                                                unknown
# Linaje                                                               BA.1.1
# Clado                                                                   GRA
# Mutaciones                (NSP5_P132H,Spike_H69del,Spike_T95I,Spike_A67V...
#
#                                                          36    \
# GISAID ID                                      EPI_ISL_491941
# Unnamed: 1                                                NaN
# Virus name                      hCoV-19/Ecuador/USFQ-133/2020
# FECHA DE COLECCIÓN                                 2020-05-02
# FECHA DE SUBIDA A GISAID                           2020-07-17
# PROVINCIA                                          Galápagos
# CIUDAD                                          San Cristóbal
# TIPO                                              Ambulatorio
# Genero                                                   Male
# Edad                                                       54
# Linaje                                                B.1.225
# Clado                                                       G
# Mutaciones                (NSP9_T77I,NSP12_P323L,Spike_D614G)
#
#                                                                        237   \
# GISAID ID                                                   EPI_ISL_2086701
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-1063/2021
# FECHA DE COLECCIÓN                                               2021-04-03
# FECHA DE SUBIDA A GISAID                                         2021-05-13
# PROVINCIA                                                           Manabi
# CIUDAD                                                           Portoviejo
# TIPO                                                               Hospital
# Genero                                                               Female
# Edad                                                                     39
# Linaje                                                            B.1.1.348
# Clado                                                                    GR
# Mutaciones                (N_T379L,N_K375R,N_K373R,Spike_D1199H,Spike_G1...
#
#                                                                        1497  \
# GISAID ID                                                  EPI_ISL_12109485
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-3290/2022
# FECHA DE COLECCIÓN                                               2022-03-23
# FECHA DE SUBIDA A GISAID                                         2022-04-18
# PROVINCIA                                                         Pichincha
# CIUDAD                                                                QUITO
# TIPO                                                            Ambulatorio
# Genero                                                                 Male
# Edad                                                                unknown
# Linaje                                                               BA.1.1
# Clado                                                                   GRA
# Mutaciones                (NSP5_P132H,Spike_H69del,Spike_T95I,Spike_A67V...
#
#                                                             382
# GISAID ID                                        EPI_ISL_2689830
# Unnamed: 1                                                   NaN
# Virus name                hCoV-19/Ecuador/USFQ-1538-UTPL104/2021
# FECHA DE COLECCIÓN                                    2021-06-15
# FECHA DE SUBIDA A GISAID                              2021-06-25
# PROVINCIA                                                  Loja
# CIUDAD                                                  Saraguro
# TIPO                                                 Ambulatorio
# Genero                                                      Male
# Edad                                                     unknown
# Linaje                                                       B.1
# Clado                                                          G
# Mutaciones                                         (NSP12_P323L)

# %%
muta.head().T
# Out:
#                                                    0        1        2  \
# 0I (Alpha, V1) (B.1.1.7)      Principales mutaciones  S:D614G      NaN
# 20H (Beta, V2) (B.1.351)                         NaN  S:D614G  S:E484K
# 20J (Gamma, V3) (P.1)                            NaN  S:D614G  S:E484K
# 21A (Delta) (B.1.617.2)                          NaN  S:D614G      NaN
# 21B (Kappa) (B.1.617.1)                          NaN  S:D614G  S:E484Q
# 21K (Omicron) (BA.1)                             NaN  S:D614G  S:E484A
# 21L (Omicron) (BA.2)                             NaN  S:D614G  S:E484A
# 22A & 22B (Omicron) (BA.4&5)                     NaN  S:D614G  S:E484A
# 22C (Omicron) (BA.2.12.1)                        NaN  S:D614G  S:E484A
# 21D (Eta) (B.1.525)                              NaN  S:D614G  S:E484K
# 21F (Iota) (B.1.526)                             NaN  S:D614G  S:E484K
# 21G (Lambda) (C.37)                              NaN  S:D614G      NaN
# 21H (Mu) (B.1.621)                               NaN  S:D614G  S:E484K
#
#                                     3        4
# 0I (Alpha, V1) (B.1.1.7)      S:P681H  S:N501Y
# 20H (Beta, V2) (B.1.351)          NaN  S:N501Y
# 20J (Gamma, V3) (P.1)             NaN  S:N501Y
# 21A (Delta) (B.1.617.2)       S:P681R      NaN
# 21B (Kappa) (B.1.617.1)       S:P681R      NaN
# 21K (Omicron) (BA.1)          S:P681H  S:N501Y
# 21L (Omicron) (BA.2)          S:P681H  S:N501Y
# 22A & 22B (Omicron) (BA.4&5)  S:P681H  S:N501Y
# 22C (Omicron) (BA.2.12.1)     S:P681H  S:N501Y
# 21D (Eta) (B.1.525)               NaN      NaN
# 21F (Iota) (B.1.526)              NaN      NaN
# 21G (Lambda) (C.37)               NaN      NaN
# 21H (Mu) (B.1.621)            S:P681H  S:N501Y

# %% [markdown]
# #### __Conceptos Importantes__
# ##### <span style="color:#a11508;"> Linaje </span>
# En microbiología, el término linaje se refiere a una rama evolutiva de una especie o un grupo de organismos que comparten una ascendencia común. Se puede pensar en un linaje como un árbol genealógico de una especie, donde las ramas representan diferentes cepas o subespecies que evolucionan a lo largo del tiempo. Los linajes pueden ser identificados por diferentes características, como la secuencia del ADN o la presencia o ausencia de ciertos genes o marcadores bioquímicos. La identificación y seguimiento de los linajes de los microorganismos son importantes en la investigación de enfermedades infecciosas y en la evaluación de la eficacia de los tratamientos y vacunas.
#
# En resumen, un linaje es una rama evolutiva de una especie o grupo de organismos que comparten una ascendencia común.
#
# ##### <span style="color:#a11508;"> Clado </span>
# En microbiología, un clado es un grupo de organismos que incluyen un ancestro común y todos sus descendientes. Se utiliza para clasificar a los organismos según su relación evolutiva y se representa en un árbol filogenético. Los miembros de un clado tienen características similares y comparten una serie de características derivadas que los distinguen de otros grupos.
#
# En un árbol filogenético, los clados se representan por un nodo, que es el punto donde se bifurca el árbol y se separan los linajes evolutivos. Los clados se forman cuando un grupo de organismos diverge de un ancestro común y desarrollan nuevas características a lo largo del tiempo.
#
# El uso de los clados es importante en la clasificación y nomenclatura de los microorganismos, ya que proporciona una forma sistemática de agrupar y describir a los organismos basados en su historia evolutiva.
#
# En resumen, un clado es un grupo de organismos que incluyen un ancestro común y todos sus descendientes y se utiliza para clasificar a los organismos según su relación evolutiva.
#
# ##### <span style="color:#a11508;"> Mutaciones </span>
# En microbiología, una mutación es un cambio en la secuencia del ADN que puede ocurrir naturalmente o ser provocado por agentes mutagénicos como la radiación o productos químicos. Las mutaciones pueden ser puntuales o afectar estructuras más complejas, y pueden ser beneficiosas, perjudiciales o neutras para el organismo. Su impacto depende del tipo de cambio que se produce en la secuencia del ADN y de la función de los genes afectados. Las mutaciones son importantes en la evolución de los microorganismos y pueden ser relevantes en la investigación y diagnóstico de enfermedades infecciosas, ya que pueden conferir resistencia a los antimicrobianos o alterar la virulencia del microorganismo.
#
# En resumen, una mutación es un cambio en la secuencia del ADN que puede ser natural o provocado, puede ser beneficioso, perjudicial o neutro para el organismo, y puede ocurrir en diferentes etapas del ciclo de vida del microorganismo. Las mutaciones son importantes en la evolución y en el diagnóstico de enfermedades infecciosas.

# %% [markdown]
# ### Columns and Index

# %%
(df
 .rename(columns=lambda c:unidecode(c.replace(' ', '_').lower()))
 .drop(columns=['gisaid_id', 'unnamed:_1', 'fecha_de_subida_a_gisaid'])
)
# Out:
#                               virus_name fecha_de_coleccion    provincia  \
# 0            hCoV-19/Ecuador/HEE-01/2020         2020-03-09    Pichincha
# 1     hCoV-19/Ecuador/HGSQ-USFQ-018/2020         2020-03-30    Pichincha
# 2     hCoV-19/Ecuador/HGSQ-USFQ-007/2020         2020-03-30    Pichincha
# 3     hCoV-19/Ecuador/HGSQ-USFQ-010/2020         2020-03-30    Pichincha
# 4          hCoV-19/Ecuador/USFQ-020/2020         2020-04-17    Los Rios
# ...                                  ...                ...          ...
# 1643      hCoV-19/Ecuador/USFQ-3477/2022         2022-05-27   Pichincha
# 1644      hCoV-19/Ecuador/USFQ-3479/2022         2022-05-28   Pichincha
# 1645      hCoV-19/Ecuador/USFQ-3482/2022         2022-05-29   Pichincha
# 1646      hCoV-19/Ecuador/USFQ-3483/2022         2022-05-25   Pichincha
# 1647      hCoV-19/Ecuador/USFQ-3484/2022         2022-05-30   Pichincha
#
#         ciudad         tipo  genero edad  linaje clado  \
# 0        QUITO     Hospital    Male   57    B.55     L
# 1        QUITO     Hospital    Male   27   B.1.1    GR
# 2        QUITO     Hospital    Male   40  B.1.14     O
# 3        QUITO     Hospital    Male   39  B.1.14     O
# 4     BABAHOYO     Hospital  Female   50  B.1.67     G
# ...        ...          ...     ...  ...     ...   ...
# 1643     Quito  Ambulatorio    Male   42    BA.2   GRA
# 1644     Quito  Ambulatorio    Male   54    BA.2   GRA
# 1645     Quito  Ambulatorio    Male    5    BA.2   GRA
# 1646     Quito  Ambulatorio    Male   34    BA.2   GRA
# 1647     Quito  Ambulatorio  Female   67  BA.2.9   GRA
#
#                                              mutaciones
# 0                                          Spike E1207V
# 1     (N_R203K,N_G204R,NSP12_P323L,NSP3_L431F,Spike_...
# 2     (NSP15_S293T,NS3_Q38P,NS3_V163T,NS3_R122E,NS3_...
# 3     (NSP15_S293T,NS3_Q38P,NS3_V163T,NS3_R122E,NS3_...
# 4                             (NSP12_P323L,Spike_D614G)
# ...                                                 ...
# 1643  (NSP5_P132H,NSP3_G489S,NSP4_T327I,Spike_S373P,...
# 1644  (NSP5_P132H,NSP3_G489S,Spike_L24del,NSP4_T327I...
# 1645  (NSP5_P132H,NSP3_G489S,NSP4_T327I,Spike_S373P,...
# 1646  (NSP5_P132H,Spike_S371F,NSP3_G489S,NSP13_R392C...
# 1647  (NSP5_P132H,NSP3_G489S,Spike_L24del,NSP4_T327I...
#
# [1648 rows x 10 columns]

# %% [markdown]
# ### Datetimes

# %%
(df
 .rename(columns=lambda c:unidecode(c.replace(' ', '_').lower()))
 .drop(columns=['gisaid_id', 'unnamed:_1', 'fecha_de_subida_a_gisaid'])
 .assign(fecha_de_coleccion=lambda df_:pd.to_datetime(df_.fecha_de_coleccion))
 .set_index('fecha_de_coleccion')
)
# Out:
#                                             virus_name    provincia    ciudad  \
# fecha_de_coleccion
# 2020-03-09                 hCoV-19/Ecuador/HEE-01/2020    Pichincha     QUITO
# 2020-03-30          hCoV-19/Ecuador/HGSQ-USFQ-018/2020    Pichincha     QUITO
# 2020-03-30          hCoV-19/Ecuador/HGSQ-USFQ-007/2020    Pichincha     QUITO
# 2020-03-30          hCoV-19/Ecuador/HGSQ-USFQ-010/2020    Pichincha     QUITO
# 2020-04-17               hCoV-19/Ecuador/USFQ-020/2020    Los Rios   BABAHOYO
# ...                                                ...          ...       ...
# 2022-05-27              hCoV-19/Ecuador/USFQ-3477/2022   Pichincha      Quito
# 2022-05-28              hCoV-19/Ecuador/USFQ-3479/2022   Pichincha      Quito
# 2022-05-29              hCoV-19/Ecuador/USFQ-3482/2022   Pichincha      Quito
# 2022-05-25              hCoV-19/Ecuador/USFQ-3483/2022   Pichincha      Quito
# 2022-05-30              hCoV-19/Ecuador/USFQ-3484/2022   Pichincha      Quito
#
#                            tipo  genero edad  linaje clado  \
# fecha_de_coleccion
# 2020-03-09             Hospital    Male   57    B.55     L
# 2020-03-30             Hospital    Male   27   B.1.1    GR
# 2020-03-30             Hospital    Male   40  B.1.14     O
# 2020-03-30             Hospital    Male   39  B.1.14     O
# 2020-04-17             Hospital  Female   50  B.1.67     G
# ...                         ...     ...  ...     ...   ...
# 2022-05-27          Ambulatorio    Male   42    BA.2   GRA
# 2022-05-28          Ambulatorio    Male   54    BA.2   GRA
# 2022-05-29          Ambulatorio    Male    5    BA.2   GRA
# 2022-05-25          Ambulatorio    Male   34    BA.2   GRA
# 2022-05-30          Ambulatorio  Female   67  BA.2.9   GRA
#
#                                                            mutaciones
# fecha_de_coleccion
# 2020-03-09                                               Spike E1207V
# 2020-03-30          (N_R203K,N_G204R,NSP12_P323L,NSP3_L431F,Spike_...
# 2020-03-30          (NSP15_S293T,NS3_Q38P,NS3_V163T,NS3_R122E,NS3_...
# 2020-03-30          (NSP15_S293T,NS3_Q38P,NS3_V163T,NS3_R122E,NS3_...
# 2020-04-17                                  (NSP12_P323L,Spike_D614G)
# ...                                                               ...
# 2022-05-27          (NSP5_P132H,NSP3_G489S,NSP4_T327I,Spike_S373P,...
# 2022-05-28          (NSP5_P132H,NSP3_G489S,Spike_L24del,NSP4_T327I...
# 2022-05-29          (NSP5_P132H,NSP3_G489S,NSP4_T327I,Spike_S373P,...
# 2022-05-25          (NSP5_P132H,Spike_S371F,NSP3_G489S,NSP13_R392C...
# 2022-05-30          (NSP5_P132H,NSP3_G489S,Spike_L24del,NSP4_T327I...
#
# [1648 rows x 9 columns]

# %% [markdown]
# ### Numerical Types

# %%
(df
 .rename(columns=lambda c:unidecode(c.replace(' ', '_').lower()))
 .drop(columns=['gisaid_id', 'unnamed:_1', 'fecha_de_subida_a_gisaid'])
 .drop(index=df[df.Edad.str.contains('months')==True].index)
 .assign(fecha_de_coleccion=lambda df_:pd.to_datetime(df_.fecha_de_coleccion),
         edad=lambda df_:(df_
                          .edad
                          .replace(to_replace=['unknown', 'M'], value=np.nan)), # neither floats nor int are nullable
        )
 .set_index('fecha_de_coleccion')
)
# Out:
#                                             virus_name    provincia    ciudad  \
# fecha_de_coleccion
# 2020-03-09                 hCoV-19/Ecuador/HEE-01/2020    Pichincha     QUITO
# 2020-03-30          hCoV-19/Ecuador/HGSQ-USFQ-018/2020    Pichincha     QUITO
# 2020-03-30          hCoV-19/Ecuador/HGSQ-USFQ-007/2020    Pichincha     QUITO
# 2020-03-30          hCoV-19/Ecuador/HGSQ-USFQ-010/2020    Pichincha     QUITO
# 2020-04-17               hCoV-19/Ecuador/USFQ-020/2020    Los Rios   BABAHOYO
# ...                                                ...          ...       ...
# 2022-05-27              hCoV-19/Ecuador/USFQ-3477/2022   Pichincha      Quito
# 2022-05-28              hCoV-19/Ecuador/USFQ-3479/2022   Pichincha      Quito
# 2022-05-29              hCoV-19/Ecuador/USFQ-3482/2022   Pichincha      Quito
# 2022-05-25              hCoV-19/Ecuador/USFQ-3483/2022   Pichincha      Quito
# 2022-05-30              hCoV-19/Ecuador/USFQ-3484/2022   Pichincha      Quito
#
#                            tipo  genero edad  linaje clado  \
# fecha_de_coleccion
# 2020-03-09             Hospital    Male   57    B.55     L
# 2020-03-30             Hospital    Male   27   B.1.1    GR
# 2020-03-30             Hospital    Male   40  B.1.14     O
# 2020-03-30             Hospital    Male   39  B.1.14     O
# 2020-04-17             Hospital  Female   50  B.1.67     G
# ...                         ...     ...  ...     ...   ...
# 2022-05-27          Ambulatorio    Male   42    BA.2   GRA
# 2022-05-28          Ambulatorio    Male   54    BA.2   GRA
# 2022-05-29          Ambulatorio    Male    5    BA.2   GRA
# 2022-05-25          Ambulatorio    Male   34    BA.2   GRA
# 2022-05-30          Ambulatorio  Female   67  BA.2.9   GRA
#
#                                                            mutaciones
# fecha_de_coleccion
# 2020-03-09                                               Spike E1207V
# 2020-03-30          (N_R203K,N_G204R,NSP12_P323L,NSP3_L431F,Spike_...
# 2020-03-30          (NSP15_S293T,NS3_Q38P,NS3_V163T,NS3_R122E,NS3_...
# 2020-03-30          (NSP15_S293T,NS3_Q38P,NS3_V163T,NS3_R122E,NS3_...
# 2020-04-17                                  (NSP12_P323L,Spike_D614G)
# ...                                                               ...
# 2022-05-27          (NSP5_P132H,NSP3_G489S,NSP4_T327I,Spike_S373P,...
# 2022-05-28          (NSP5_P132H,NSP3_G489S,Spike_L24del,NSP4_T327I...
# 2022-05-29          (NSP5_P132H,NSP3_G489S,NSP4_T327I,Spike_S373P,...
# 2022-05-25          (NSP5_P132H,Spike_S371F,NSP3_G489S,NSP13_R392C...
# 2022-05-30          (NSP5_P132H,NSP3_G489S,Spike_L24del,NSP4_T327I...
#
# [1646 rows x 9 columns]

# %% [markdown]
# ### Non-Numeric Types

# %%
df.columns
# Out:
# Index(['provincia', 'ciudad', 'tipo', 'genero', 'edad', 'linaje', 'clado',
#        'E_A41V', 'E_L73F', 'E_R61L',
#        ...
#        'Spike_Y145Del', 'Spike_Y145N', 'Spike_Y145P', 'Spike_Y145T',
#        'Spike_Y248Del', 'Spike_Y248F', 'Spike_Y449N', 'Spike_Y505H',
#        'virus_name_unidentified', 'count_muts'],
#       dtype='object', length=2010)

# %%
def get_mutaciones(df):

    dums = \
    (df
     .mutaciones
     .str.replace('[()]', '', regex=True)
     .str.get_dummies(sep=',')
     .rename(columns=lambda c: '__' + c)
    )
    
    return pd.concat([df, dums], axis=1)

df = \
(df
 .rename(columns=lambda c:unidecode(c.replace(' ', '_').lower()))
 .drop(index=df[df.Edad.str.contains('months')==True].index)
 .drop(columns=['gisaid_id', 'unnamed:_1', 'fecha_de_subida_a_gisaid'])
 .dropna(subset=['linaje', 'clado', 'mutaciones'])
 .applymap(lambda tx: unidecode(tx.title()) if isinstance(tx, str) else tx)
 .pipe(get_mutaciones)
 .assign(fecha_de_coleccion=lambda df_:pd.to_datetime(df_.fecha_de_coleccion),
         edad=lambda df_:(df_
                          .edad
                          .replace(to_replace=['Unknown', 'M'], value=np.nan)), # neither floats nor int are nullable
         virus_name_unidentified=lambda df_:(df_
                                             .virus_name
                                             .str.split('/', expand=True)[2]),
         count_muts=lambda df_:(df_
                                [[c for c in df_.columns if c not in ['provincia', 'ciudad', 'tipo', 
                                                                      'genero', 'edad', 'linaje', 
                                                                      'clado', 'virus_name', 'mutaciones',
                                                                      'fecha_de_coleccion', 'virus_name_unidentified']]]
                                .apply(lambda s: s.sum(), axis=1)),
        )
 .drop(columns=['virus_name', 'mutaciones'])
 .set_index('fecha_de_coleccion')
)
# Out:
#                       provincia    ciudad         tipo  genero edad  linaje  \
# fecha_de_coleccion
# 2020-03-09            Pichincha     Quito     Hospital    Male   57    B.55
# 2020-03-30            Pichincha     Quito     Hospital    Male   27   B.1.1
# 2020-03-30            Pichincha     Quito     Hospital    Male   40  B.1.14
# 2020-03-30            Pichincha     Quito     Hospital    Male   39  B.1.14
# 2020-04-17            Los Rios   Babahoyo     Hospital  Female   50  B.1.67
# ...                         ...       ...          ...     ...  ...     ...
# 2022-05-27           Pichincha      Quito  Ambulatorio    Male   42    Ba.2
# 2022-05-28           Pichincha      Quito  Ambulatorio    Male   54    Ba.2
# 2022-05-29           Pichincha      Quito  Ambulatorio    Male    5    Ba.2
# 2022-05-25           Pichincha      Quito  Ambulatorio    Male   34    Ba.2
# 2022-05-30           Pichincha      Quito  Ambulatorio  Female   67  Ba.2.9
#
#                    clado  __E_A41V  __E_L73F  __E_R61L  ...  __Spike_Y145Del  \
# fecha_de_coleccion                                      ...
# 2020-03-09             L         0         0         0  ...                0
# 2020-03-30            Gr         0         0         0  ...                0
# 2020-03-30             O         0         0         0  ...                0
# 2020-03-30             O         0         0         0  ...                0
# 2020-04-17             G         0         0         0  ...                0
# ...                  ...       ...       ...       ...  ...              ...
# 2022-05-27           Gra         0         0         0  ...                0
# 2022-05-28           Gra         0         0         0  ...                0
# 2022-05-29           Gra         0         0         0  ...                0
# 2022-05-25           Gra         0         0         0  ...                0
# 2022-05-30           Gra         0         0         0  ...                0
#
#                     __Spike_Y145N  __Spike_Y145P  __Spike_Y145T  \
# fecha_de_coleccion
# 2020-03-09                      0              0              0
# 2020-03-30                      0              0              0
# 2020-03-30                      0              0              0
# 2020-03-30                      0              0              0
# 2020-04-17                      0              0              0
# ...                           ...            ...            ...
# 2022-05-27                      0              0              0
# 2022-05-28                      0              0              0
# 2022-05-29                      0              0              0
# 2022-05-25                      0              0              0
# 2022-05-30                      0              0              0
#
#                     __Spike_Y248Del  __Spike_Y248F  __Spike_Y449N  \
# fecha_de_coleccion
# 2020-03-09                        0              0              0
# 2020-03-30                        0              0              0
# 2020-03-30                        0              0              0
# 2020-03-30                        0              0              0
# 2020-04-17                        0              0              0
# ...                             ...            ...            ...
# 2022-05-27                        0              0              0
# 2022-05-28                        0              0              0
# 2022-05-29                        0              0              0
# 2022-05-25                        0              0              0
# 2022-05-30                        0              0              0
#
#                     __Spike_Y505H  virus_name_unidentified  count_muts
# fecha_de_coleccion
# 2020-03-09                      0                   Hee-01           1
# 2020-03-30                      0            Hgsq-Usfq-018           5
# 2020-03-30                      0            Hgsq-Usfq-007          18
# 2020-03-30                      0            Hgsq-Usfq-010          18
# 2020-04-17                      0                 Usfq-020           2
# ...                           ...                      ...         ...
# 2022-05-27                      1                Usfq-3477          53
# 2022-05-28                      1                Usfq-3479          61
# 2022-05-29                      1                Usfq-3482          51
# 2022-05-25                      1                Usfq-3483          47
# 2022-05-30                      1                Usfq-3484          56
#
# [1645 rows x 2010 columns]

# %% [markdown]
# ### Tweak Data

# %%
def get_mutaciones(df):

    dums = \
    (df
     .mutaciones
     .str.replace('[()]', '', regex=True)
     .str.get_dummies(sep=',')
     .rename(columns=lambda c: '__' + c)
    )
    
    return pd.concat([df, dums], axis=1)

def tweak_covid(df):
    return (df
     .rename(columns=lambda c:unidecode(c.replace(' ', '_').lower()))
     .drop(index=df[df.Edad.str.contains('months')==True].index)
     .drop(columns=['gisaid_id', 'unnamed:_1', 'fecha_de_subida_a_gisaid'])
     .dropna(subset=['linaje', 'clado', 'mutaciones'])
     .applymap(lambda tx: unidecode(tx.title()) if isinstance(tx, str) else tx)
     .pipe(get_mutaciones)
     .assign(fecha_de_coleccion=lambda df_:pd.to_datetime(df_.fecha_de_coleccion),
             edad=lambda df_:(df_
                              .edad
                              .replace(to_replace=['Unknown', 'M'], value=np.nan)), # neither floats nor int are nullable
             virus_name_unidentified=lambda df_:(df_
                                                 .virus_name
                                                 .str.split('/', expand=True)[2]),
             count_muts=lambda df_:(df_
                                    [[c for c in df_.columns if c not in ['provincia', 'ciudad', 'tipo', 
                                                                          'genero', 'edad', 'linaje', 
                                                                          'clado', 'virus_name', 'mutaciones',
                                                                          'fecha_de_coleccion', 'virus_name_unidentified']]]
                                    .apply(lambda s: s.sum(), axis=1)),
            )
     .drop(columns=['virus_name', 'mutaciones'])
     .set_index('fecha_de_coleccion')
    )

# %%
def check_memory(df):
    print(df.memory_usage(deep=True).sum() / 1000000)
    return df

def get_shape(df):
    print(df.shape)
    return df

# %%
# @TODOS
# @ add column named concern = True if lineage/variant is of concern### Anomalies
# @ add column named count_muts = count of the number of mutations
# @ add column named avg_muts = average of the number per variant
# @
