# %%
import pandas as pd
import numpy as np
import seaborn as sns
from unidecode import unidecode
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

sns.set(style='whitegrid', rc={'figure.figsize':(16, 4)})

# I want crisp graphics, so we'll output SVG
# %config InlineBackend.figure_format = 'svg'


raw = pd.read_csv('../data/raw/raw_base_junio.csv')
cas_ = pd.read_csv('https://raw.githubusercontent.com/andrab/ecuacovid/master/datos_crudos/ecuacovid.csv')

# %%
def tweak_covid(df):
    return (df
         .rename(columns=lambda c:unidecode(c.replace(' ', '_').lower()))
         .drop(columns=['gisaid_id', 'unnamed:_1', 'fecha_de_subida_a_gisaid'])
         .drop(index=df[df.Edad.str.contains('months')==True].index)
         .dropna(subset=['linaje', 'clado', 'mutaciones'])
         .applymap(lambda tx: unidecode(tx.title()) if isinstance(tx, str) else tx)
         .assign(fecha_de_coleccion=lambda df_:pd.to_datetime(df_.fecha_de_coleccion),
                 edad=lambda df_:(df_
                                  .edad
                                  .replace(to_replace=['Unknown', 'M'], value=np.nan)), # neither floats nor int are nullable
                 virus_name_unidentified=lambda df_:(df_
                                                     .virus_name
                                                     .str.split('/', expand=True)[2]),
                 count_muts=lambda df_:(df_
                                        .mutaciones
                                        .str.replace(pat='[()]', repl='', regex=True)
                                        .str.split(',')
                                        .apply(lambda l:len(l) if isinstance(l, list) else l)
                                        .astype('uint16'))
                )
         .drop(columns=['virus_name'])
         .set_index('fecha_de_coleccion')
        )

df = tweak_covid(raw)

# %%
df
# Out:
#                       provincia    ciudad         tipo  genero edad  linaje  \
# fecha_de_coleccion
# 2020-03-09            Pichincha     Quito     Hospital    Male   57    B.55
# 2020-03-30            Pichincha     Quito     Hospital    Male   27   B.1.1
# 2020-03-30            Pichincha     Quito     Hospital    Male   40  B.1.14
# 2020-03-30            Pichincha     Quito     Hospital    Male   39  B.1.14
# 2020-04-17            Los Rios   Babahoyo     Hospital  Female   50  B.1.67
# ...                         ...       ...          ...     ...  ...     ...
# 2022-05-27           Pichincha      Quito  Ambulatorio    Male   42    Ba.2
# 2022-05-28           Pichincha      Quito  Ambulatorio    Male   54    Ba.2
# 2022-05-29           Pichincha      Quito  Ambulatorio    Male    5    Ba.2
# 2022-05-25           Pichincha      Quito  Ambulatorio    Male   34    Ba.2
# 2022-05-30           Pichincha      Quito  Ambulatorio  Female   67  Ba.2.9
#
#                    clado                                         mutaciones  \
# fecha_de_coleccion
# 2020-03-09             L                                       Spike E1207V
# 2020-03-30            Gr  (N_R203K,N_G204R,Nsp12_P323L,Nsp3_L431F,Spike_...
# 2020-03-30             O  (Nsp15_S293T,Ns3_Q38P,Ns3_V163T,Ns3_R122E,Ns3_...
# 2020-03-30             O  (Nsp15_S293T,Ns3_Q38P,Ns3_V163T,Ns3_R122E,Ns3_...
# 2020-04-17             G                          (Nsp12_P323L,Spike_D614G)
# ...                  ...                                                ...
# 2022-05-27           Gra  (Nsp5_P132H,Nsp3_G489S,Nsp4_T327I,Spike_S373P,...
# 2022-05-28           Gra  (Nsp5_P132H,Nsp3_G489S,Spike_L24Del,Nsp4_T327I...
# 2022-05-29           Gra  (Nsp5_P132H,Nsp3_G489S,Nsp4_T327I,Spike_S373P,...
# 2022-05-25           Gra  (Nsp5_P132H,Spike_S371F,Nsp3_G489S,Nsp13_R392C...
# 2022-05-30           Gra  (Nsp5_P132H,Nsp3_G489S,Spike_L24Del,Nsp4_T327I...
#
#                    virus_name_unidentified  count_muts
# fecha_de_coleccion
# 2020-03-09                          Hee-01           1
# 2020-03-30                   Hgsq-Usfq-018           5
# 2020-03-30                   Hgsq-Usfq-007          18
# 2020-03-30                   Hgsq-Usfq-010          18
# 2020-04-17                        Usfq-020           2
# ...                                    ...         ...
# 2022-05-27                       Usfq-3477          53
# 2022-05-28                       Usfq-3479          61
# 2022-05-29                       Usfq-3482          51
# 2022-05-25                       Usfq-3483          47
# 2022-05-30                       Usfq-3484          56
#
# [1645 rows x 10 columns]

# %% [markdown]
# ### Exploring the prevalence of variants

# %%
# Which variants have occurred more frequently

from IPython.display import display

with pd.option_context('max_rows', None):
    display(
        (df
         .groupby(['linaje'])
         .agg({'linaje':'count'})
         .rename(columns={'linaje':'Rel. Perc'})
         .apply(lambda s: s / s.sum())
         .sort_values(by='Rel. Perc', ascending=False)
         .style
         .set_caption('Prevalencia de Variantes')
         .background_gradient(axis=None, vmin=0, vmax=0.20, cmap='inferno')
         .format('{:.4f}')
        )     
    )
# Out:
# <style type="text/css">
# #T_baf11_row0_col0 {
#   background-color: #f5d949;
#   color: #000000;
# }
# #T_baf11_row1_col0 {
#   background-color: #d34743;
#   color: #f1f1f1;
# }
# #T_baf11_row2_col0 {
#   background-color: #902568;
#   color: #f1f1f1;
# }
# #T_baf11_row3_col0 {
#   background-color: #751b6e;
#   color: #f1f1f1;
# }
# #T_baf11_row4_col0 {
#   background-color: #71196e;
#   color: #f1f1f1;
# }
# #T_baf11_row5_col0 {
#   background-color: #62146e;
#   color: #f1f1f1;
# }
# #T_baf11_row6_col0, #T_baf11_row7_col0 {
#   background-color: #380962;
#   color: #f1f1f1;
# }
# #T_baf11_row8_col0 {
#   background-color: #310a5c;
#   color: #f1f1f1;
# }
# #T_baf11_row9_col0 {
#   background-color: #2d0b59;
#   color: #f1f1f1;
# }
# #T_baf11_row10_col0, #T_baf11_row11_col0 {
#   background-color: #1f0c48;
#   color: #f1f1f1;
# }
# #T_baf11_row12_col0 {
#   background-color: #160b39;
#   color: #f1f1f1;
# }
# #T_baf11_row13_col0 {
#   background-color: #10092d;
#   color: #f1f1f1;
# }
# #T_baf11_row14_col0 {
#   background-color: #0d0829;
#   color: #f1f1f1;
# }
# #T_baf11_row15_col0 {
#   background-color: #0b0724;
#   color: #f1f1f1;
# }
# #T_baf11_row16_col0, #T_baf11_row17_col0, #T_baf11_row18_col0 {
#   background-color: #09061f;
#   color: #f1f1f1;
# }
# #T_baf11_row19_col0 {
#   background-color: #08051d;
#   color: #f1f1f1;
# }
# #T_baf11_row20_col0 {
#   background-color: #060419;
#   color: #f1f1f1;
# }
# #T_baf11_row21_col0, #T_baf11_row22_col0 {
#   background-color: #050417;
#   color: #f1f1f1;
# }
# #T_baf11_row23_col0, #T_baf11_row24_col0 {
#   background-color: #040314;
#   color: #f1f1f1;
# }
# #T_baf11_row25_col0, #T_baf11_row26_col0, #T_baf11_row27_col0 {
#   background-color: #030210;
#   color: #f1f1f1;
# }
# #T_baf11_row28_col0, #T_baf11_row29_col0 {
#   background-color: #02020e;
#   color: #f1f1f1;
# }
# #T_baf11_row30_col0, #T_baf11_row31_col0, #T_baf11_row32_col0 {
#   background-color: #02020c;
#   color: #f1f1f1;
# }
# #T_baf11_row33_col0 {
#   background-color: #02010a;
#   color: #f1f1f1;
# }
# #T_baf11_row34_col0, #T_baf11_row35_col0, #T_baf11_row36_col0, #T_baf11_row37_col0, #T_baf11_row38_col0, #T_baf11_row39_col0, #T_baf11_row40_col0, #T_baf11_row41_col0 {
#   background-color: #010108;
#   color: #f1f1f1;
# }
# #T_baf11_row42_col0, #T_baf11_row43_col0, #T_baf11_row44_col0, #T_baf11_row45_col0, #T_baf11_row46_col0, #T_baf11_row47_col0 {
#   background-color: #010106;
#   color: #f1f1f1;
# }
# #T_baf11_row48_col0, #T_baf11_row49_col0, #T_baf11_row50_col0, #T_baf11_row51_col0, #T_baf11_row52_col0, #T_baf11_row53_col0, #T_baf11_row54_col0, #T_baf11_row55_col0, #T_baf11_row56_col0, #T_baf11_row57_col0, #T_baf11_row58_col0, #T_baf11_row59_col0, #T_baf11_row60_col0, #T_baf11_row61_col0, #T_baf11_row62_col0 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_baf11_row63_col0, #T_baf11_row64_col0, #T_baf11_row65_col0, #T_baf11_row66_col0, #T_baf11_row67_col0, #T_baf11_row68_col0, #T_baf11_row69_col0, #T_baf11_row70_col0, #T_baf11_row71_col0, #T_baf11_row72_col0, #T_baf11_row73_col0, #T_baf11_row74_col0, #T_baf11_row75_col0, #T_baf11_row76_col0, #T_baf11_row77_col0, #T_baf11_row78_col0, #T_baf11_row79_col0, #T_baf11_row80_col0, #T_baf11_row81_col0, #T_baf11_row82_col0, #T_baf11_row83_col0, #T_baf11_row84_col0, #T_baf11_row85_col0, #T_baf11_row86_col0, #T_baf11_row87_col0, #T_baf11_row88_col0, #T_baf11_row89_col0, #T_baf11_row90_col0, #T_baf11_row91_col0, #T_baf11_row92_col0, #T_baf11_row93_col0, #T_baf11_row94_col0, #T_baf11_row95_col0 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_baf11_">
#   <caption>Prevalencia de Variantes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Rel. Perc</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >linaje</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_baf11_level0_row0" class="row_heading level0 row0" >Ba.1.1</th>
#       <td id="T_baf11_row0_col0" class="data row0 col0" >0.1812</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row1" class="row_heading level0 row1" >B.1</th>
#       <td id="T_baf11_row1_col0" class="data row1 col0" >0.1137</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row2" class="row_heading level0 row2" >Ba.1.14</th>
#       <td id="T_baf11_row2_col0" class="data row2 col0" >0.0784</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row3" class="row_heading level0 row3" >B.1.1</th>
#       <td id="T_baf11_row3_col0" class="data row3 col0" >0.0650</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row4" class="row_heading level0 row4" >B.1.1.7</th>
#       <td id="T_baf11_row4_col0" class="data row4 col0" >0.0632</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row5" class="row_heading level0 row5" >Ay.122</th>
#       <td id="T_baf11_row5_col0" class="data row5 col0" >0.0559</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row6" class="row_heading level0 row6" >P.1</th>
#       <td id="T_baf11_row6_col0" class="data row6 col0" >0.0359</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row7" class="row_heading level0 row7" >B.1.621</th>
#       <td id="T_baf11_row7_col0" class="data row7 col0" >0.0353</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row8" class="row_heading level0 row8" >B.1.526</th>
#       <td id="T_baf11_row8_col0" class="data row8 col0" >0.0322</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row9" class="row_heading level0 row9" >Ay.100</th>
#       <td id="T_baf11_row9_col0" class="data row9 col0" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row10" class="row_heading level0 row10" >C.37</th>
#       <td id="T_baf11_row10_col0" class="data row10 col0" >0.0243</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row11" class="row_heading level0 row11" >Ba.2</th>
#       <td id="T_baf11_row11_col0" class="data row11 col0" >0.0243</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row12" class="row_heading level0 row12" >Ba.1</th>
#       <td id="T_baf11_row12_col0" class="data row12 col0" >0.0201</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row13" class="row_heading level0 row13" >Unassigned</th>
#       <td id="T_baf11_row13_col0" class="data row13 col0" >0.0158</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row14" class="row_heading level0 row14" >Ba.1.15</th>
#       <td id="T_baf11_row14_col0" class="data row14 col0" >0.0146</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row15" class="row_heading level0 row15" >Ba.1.1.11</th>
#       <td id="T_baf11_row15_col0" class="data row15 col0" >0.0128</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row16" class="row_heading level0 row16" >B</th>
#       <td id="T_baf11_row16_col0" class="data row16 col0" >0.0109</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row17" class="row_heading level0 row17" >B.1.1.1</th>
#       <td id="T_baf11_row17_col0" class="data row17 col0" >0.0109</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row18" class="row_heading level0 row18" >Ba.1.18</th>
#       <td id="T_baf11_row18_col0" class="data row18 col0" >0.0109</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row19" class="row_heading level0 row19" >Ay.25.1</th>
#       <td id="T_baf11_row19_col0" class="data row19 col0" >0.0103</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row20" class="row_heading level0 row20" >B.1.1.348</th>
#       <td id="T_baf11_row20_col0" class="data row20 col0" >0.0091</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row21" class="row_heading level0 row21" >Ay.43</th>
#       <td id="T_baf11_row21_col0" class="data row21 col0" >0.0085</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row22" class="row_heading level0 row22" >Ba.2.12.1</th>
#       <td id="T_baf11_row22_col0" class="data row22 col0" >0.0079</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row23" class="row_heading level0 row23" >Ba.1.1.1</th>
#       <td id="T_baf11_row23_col0" class="data row23 col0" >0.0073</td>
#     </tr>
#     <tr>
#       <th id="T_baf11_level0_row24" class="row_heading level0 row24" >A.2.5.3</th>
#       <td id="T_baf11_row24_col0" class="data row24 col0" >0.0073</td>
#     </tr>
#     <tr>
#       <

# %% [markdown]
# ### Exploring Infection Waves

# %%
cas_ = \
(cas_
 .assign(created_at=pd.to_datetime(cas_.created_at, dayfirst=True))
 .set_index('created_at')
)

# %%
cas_
# Out:
#             muestras  muestras_pcr  positivas_total  positivas_probables  \
# created_at
# 2020-03-13       129           129                0                    0
# 2020-03-14       206           206                0                    0
# 2020-03-15       273           273                0                    0
# 2020-03-16       354           354                0                    0
# 2020-03-17       762           762                0                    0
# ...              ...           ...              ...                  ...
# 2022-09-08   3385114       3364542          1245482               247280
# 2022-09-09   3390289       3369717          1246434               247294
# 2022-09-10   3392674       3372102          1246891               247305
# 2022-09-11   3393354       3372782          1247031               247306
# 2022-09-12   3393763       3373191          1247146               247309
#
#             muestras_pcr_nuevas  pruebas_rezagadas  muertes_confirmadas  \
# created_at
# 2020-03-13                    0                106                    1
# 2020-03-14                   77                178                    2
# 2020-03-15                   67                236                    2
# 2020-03-16                   81                296                    2
# 2020-03-17                  408                651                    2
# ...                         ...                ...                  ...
# 2022-09-08                 1069             247280                25543
# 2022-09-09                 5175             247294                25545
# 2022-09-10                 2385             247305                25550
# 2022-09-11                  680             247306                25551
# 2022-09-12                  409             247309                25551
#
#             muertes_probables  muertes  muertes_nuevas  ...  \
# created_at                                              ...
# 2020-03-13                  0        1               0  ...
# 2020-03-14                  0        2               1  ...
# 2020-03-15                  0        2               0  ...
# 2020-03-16                  0        2               0  ...
# 2020-03-17                  0        2               0  ...
# ...                       ...      ...             ...  ...
# 2022-09-08              10333    35876               0  ...
# 2022-09-09              10333    35878               2  ...
# 2022-09-10              10333    35883               5  ...
# 2022-09-11              10333    35884               1  ...
# 2022-09-12              10333    35884               0  ...
#
#             rpc_hospitalizacion_camas_asignadas  \
# created_at
# 2020-03-13                                    0
# 2020-03-14                                    0
# 2020-03-15                                    0
# 2020-03-16                                    0
# 2020-03-17                                    0
# ...                                         ...
# 2022-09-08                                  127
# 2022-09-09                                  127
# 2022-09-10                                  127
# 2022-09-11                                  127
# 2022-09-12                                  126
#
#             rpc_hospitalizacion_camas_ocupadas  \
# created_at
# 2020-03-13                                   0
# 2020-03-14                                   0
# 2020-03-15                                   0
# 2020-03-16                                   0
# 2020-03-17                                   0
# ...                                        ...
# 2022-09-08                                  24
# 2022-09-09                                  22
# 2022-09-10                                  22
# 2022-09-11                                  22
# 2022-09-12                                  19
#
#             rpc_cuidado_intermedio_camas_porcentaje_ocupadas  \
# created_at
# 2020-03-13                                                 0
# 2020-03-14                                                 0
# 2020-03-15                                                 0
# 2020-03-16                                                 0
# 2020-03-17                                                 0
# ...                                                      ...
# 2022-09-08                                                 0
# 2022-09-09                                                 0
# 2022-09-10                                                 0
# 2022-09-11                                                 0
# 2022-09-12                                                 0
#
#             rpc_cuidado_intermedio_lista_espera  \
# created_at
# 2020-03-13                                    0
# 2020-03-14                                    0
# 2020-03-15                                    0
# 2020-03-16                                    0
# 2020-03-17                                    0
# ...                                         ...
# 2022-09-08                                    0
# 2022-09-09                                    0
# 2022-09-10                                    0
# 2022-09-11                                    0
# 2022-09-12                                    0
#
#             rpc_cuidado_intermedio_camas_asignadas  \
# created_at
# 2020-03-13                                       0
# 2020-03-14                                       0
# 2020-03-15                                       0
# 2020-03-16                                       0
# 2020-03-17                                       0
# ...                                            ...
# 2022-09-08                                       8
# 2022-09-09                                       8
# 2022-09-10                                       8
# 2022-09-11                                       8
# 2022-09-12                                       8
#
#             rpc_cuidado_intermedio_camas_ocupadas  \
# created_at
# 2020-03-13                                      0
# 2020-03-14                                      0
# 2020-03-15                                      0
# 2020-03-16                                      0
# 2020-03-17                                      0
# ...                                           ...
# 2022-09-08                                      0
# 2022-09-09                                      0
# 2022-09-10                                      0
# 2022-09-11                                      0
# 2022-09-12                                      0
#
#             rpc_uci_camas_porcentaje_ocupadas  rpc_uci_lista_espera  \
# created_at
# 2020-03-13                                  0                     0
# 2020-03-14                                  0                     0
# 2020-03-15                                  0                     0
# 2020-03-16                                  0                     0
# 2020-03-17                                  0                     0
# ...                                       ...                   ...
# 2022-09-08                                 13                     0
# 2022-09-09                                 13                     0
# 2022-09-10                                 13                     0
# 2022-09-11                                 13                     0
# 2022-09-12                                 13                     0
#
#             rpc_uci_camas_asignadas  rpc_uci_camas_ocupadas
# created_at
# 2020-03-13                        0                       0
# 2020-03-14                        0                       0
# 2020-03-15                        0                       0
# 2020-03-16                        0                       0
# 2020-03-17                        0                       0
# ...                             ...                     ...
# 2022-09-08                       69                       9
# 2022-09-09                       69                       9
# 2022-09-10                       69                       9
# 2022-09-11                       69                       9
# 2022-09-12                       69                       9
#
# [914 rows x 75 columns]

# %%
def remove_nonpositive(df):
    return df[df.ge(0)]

ticks_ = pd.date_range(start = '2020/03/13', end = '2022/09/12', freq = 'q')

axes = \
(cas_
 [['muertes_nuevas', 'positivas_pcr_nuevas']]
 .pipe(remove_nonpositive)
 .resample('2w')
 .sum()
 .plot(
     subplots=True,
     figsize=(12, 6),
     xlabel='',
     xticks=ticks_
 )
)

for ax, label in zip(axes, ['Nuevas Muertes', 'Nuevos Positivos']):
    ax.set_xticklabels(ticks_.format(date_format='%Y/%m'))
    ax.grid(False)
    ax.legend([label])
        
    for spine in ['top', 'right']:
        ax.spines[spine].set_visible(False)

# %% [markdown]
# The first wave appears to have taken place during April and May of 2020. From the graph, it seems to have been particularly deadly as it presents the second highest peak in deaths without a parallel rise in positive cases. It may be due to the fact that not testing was not widespread. The second wave may be place in the first quarter of 2021. In either July or August the number of deaths increases to a suspicous high. Finally, around the first quarter of 2022 there is a new high in cases. After that point cases present another peak but without impacting the death toll.

# %% [markdown]
# ### Exploring the lineages that caused the waves

# %%
(df
 .loc['2020/03':'2020/06']
 .groupby(['linaje'])
 .agg({'linaje':'count'})
 .rename(columns={'linaje':'Rel. Perc'})
 .apply(lambda s: s / s.sum())
 .sort_values(by='Rel. Perc', ascending=False)
 .style
 .set_caption('Primera Ola\t(Mar-Jun 2020)')
 .background_gradient(axis=None, vmin=0, vmax=0.20, cmap='inferno')
 .format('{:.4f}')
)
# Out:
# C:\Users\Elias\AppData\Local\Temp\ipykernel_14296\514433045.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   (df
# <style type="text/css">
# #T_270f1_row0_col0 {
#   background-color: #fcffa4;
#   color: #000000;
# }
# #T_270f1_row1_col0 {
#   background-color: #fac228;
#   color: #000000;
# }
# #T_270f1_row2_col0 {
#   background-color: #f57d15;
#   color: #f1f1f1;
# }
# #T_270f1_row3_col0 {
#   background-color: #65156e;
#   color: #f1f1f1;
# }
# #T_270f1_row4_col0, #T_270f1_row5_col0, #T_270f1_row6_col0, #T_270f1_row7_col0, #T_270f1_row8_col0, #T_270f1_row9_col0 {
#   background-color: #280b53;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_270f1_">
#   <caption>Primera Ola	(Mar-Jun 2020)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Rel. Perc</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >linaje</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_270f1_level0_row0" class="row_heading level0 row0" >B.1.1</th>
#       <td id="T_270f1_row0_col0" class="data row0 col0" >0.4571</td>
#     </tr>
#     <tr>
#       <th id="T_270f1_level0_row1" class="row_heading level0 row1" >B.1</th>
#       <td id="T_270f1_row1_col0" class="data row1 col0" >0.1714</td>
#     </tr>
#     <tr>
#       <th id="T_270f1_level0_row2" class="row_heading level0 row2" >B.1.67</th>
#       <td id="T_270f1_row2_col0" class="data row2 col0" >0.1429</td>
#     </tr>
#     <tr>
#       <th id="T_270f1_level0_row3" class="row_heading level0 row3" >B.1.14</th>
#       <td id="T_270f1_row3_col0" class="data row3 col0" >0.0571</td>
#     </tr>
#     <tr>
#       <th id="T_270f1_level0_row4" class="row_heading level0 row4" >B.1.1.1</th>
#       <td id="T_270f1_row4_col0" class="data row4 col0" >0.0286</td>
#     </tr>
#     <tr>
#       <th id="T_270f1_level0_row5" class="row_heading level0 row5" >B.1.1.10</th>
#       <td id="T_270f1_row5_col0" class="data row5 col0" >0.0286</td>
#     </tr>
#     <tr>
#       <th id="T_270f1_level0_row6" class="row_heading level0 row6" >B.1.225</th>
#       <td id="T_270f1_row6_col0" class="data row6 col0" >0.0286</td>
#     </tr>
#     <tr>
#       <th id="T_270f1_level0_row7" class="row_heading level0 row7" >B.1.371</th>
#       <td id="T_270f1_row7_col0" class="data row7 col0" >0.0286</td>
#     </tr>
#     <tr>
#       <th id="T_270f1_level0_row8" class="row_heading level0 row8" >B.1.9</th>
#       <td id="T_270f1_row8_col0" class="data row8 col0" >0.0286</td>
#     </tr>
#     <tr>
#       <th id="T_270f1_level0_row9" class="row_heading level0 row9" >B.55</th>
#       <td id="T_270f1_row9_col0" class="data row9 col0" >0.0286</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df
 .loc['2021/01':'2021/04']
 .groupby(['linaje'])
 .agg({'linaje':'count'})
 .rename(columns={'linaje':'Rel. Perc'})
 .apply(lambda s: s / s.sum())
 .sort_values(by='Rel. Perc', ascending=False)
 .style
 .set_caption('Segunda Ola\t(Mar-Jun 2020)')
 .background_gradient(axis=None, vmin=0, vmax=0.22, cmap='inferno')
 .format('{:.4f}')
)
# Out:
# <style type="text/css">
# #T_75d1e_row0_col0 {
#   background-color: #fcffa4;
#   color: #000000;
# }
# #T_75d1e_row1_col0 {
#   background-color: #fb9d07;
#   color: #000000;
# }
# #T_75d1e_row2_col0 {
#   background-color: #dd513a;
#   color: #f1f1f1;
# }
# #T_75d1e_row3_col0 {
#   background-color: #71196e;
#   color: #f1f1f1;
# }
# #T_75d1e_row4_col0, #T_75d1e_row5_col0 {
#   background-color: #65156e;
#   color: #f1f1f1;
# }
# #T_75d1e_row6_col0 {
#   background-color: #5a116e;
#   color: #f1f1f1;
# }
# #T_75d1e_row7_col0, #T_75d1e_row8_col0 {
#   background-color: #450a69;
#   color: #f1f1f1;
# }
# #T_75d1e_row9_col0 {
#   background-color: #10092d;
#   color: #f1f1f1;
# }
# #T_75d1e_row10_col0, #T_75d1e_row11_col0 {
#   background-color: #08051d;
#   color: #f1f1f1;
# }
# #T_75d1e_row12_col0, #T_75d1e_row13_col0, #T_75d1e_row14_col0, #T_75d1e_row15_col0, #T_75d1e_row16_col0, #T_75d1e_row17_col0, #T_75d1e_row18_col0, #T_75d1e_row19_col0, #T_75d1e_row20_col0, #T_75d1e_row21_col0, #T_75d1e_row22_col0, #T_75d1e_row23_col0, #T_75d1e_row24_col0, #T_75d1e_row25_col0, #T_75d1e_row26_col0 {
#   background-color: #02020e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_75d1e_">
#   <caption>Segunda Ola	(Mar-Jun 2020)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Rel. Perc</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >linaje</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75d1e_level0_row0" class="row_heading level0 row0" >B.1.1.7</th>
#       <td id="T_75d1e_row0_col0" class="data row0 col0" >0.2241</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row1" class="row_heading level0 row1" >B.1.1</th>
#       <td id="T_75d1e_row1_col0" class="data row1 col0" >0.1724</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row2" class="row_heading level0 row2" >B.1.526</th>
#       <td id="T_75d1e_row2_col0" class="data row2 col0" >0.1322</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row3" class="row_heading level0 row3" >B</th>
#       <td id="T_75d1e_row3_col0" class="data row3 col0" >0.0690</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row4" class="row_heading level0 row4" >B.1</th>
#       <td id="T_75d1e_row4_col0" class="data row4 col0" >0.0632</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row5" class="row_heading level0 row5" >P.1</th>
#       <td id="T_75d1e_row5_col0" class="data row5 col0" >0.0632</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row6" class="row_heading level0 row6" >C.37</th>
#       <td id="T_75d1e_row6_col0" class="data row6 col0" >0.0575</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row7" class="row_heading level0 row7" >B.1.1.348</th>
#       <td id="T_75d1e_row7_col0" class="data row7 col0" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row8" class="row_heading level0 row8" >B.1.1.1</th>
#       <td id="T_75d1e_row8_col0" class="data row8 col0" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row9" class="row_heading level0 row9" >A.2.5.3</th>
#       <td id="T_75d1e_row9_col0" class="data row9 col0" >0.0172</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row10" class="row_heading level0 row10" >A.2.5</th>
#       <td id="T_75d1e_row10_col0" class="data row10 col0" >0.0115</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row11" class="row_heading level0 row11" >B.1.1.411</th>
#       <td id="T_75d1e_row11_col0" class="data row11 col0" >0.0115</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row12" class="row_heading level0 row12" >C.9</th>
#       <td id="T_75d1e_row12_col0" class="data row12 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row13" class="row_heading level0 row13" >Ba.1.15</th>
#       <td id="T_75d1e_row13_col0" class="data row13 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row14" class="row_heading level0 row14" >P.1.15</th>
#       <td id="T_75d1e_row14_col0" class="data row14 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row15" class="row_heading level0 row15" >C.37.1</th>
#       <td id="T_75d1e_row15_col0" class="data row15 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row16" class="row_heading level0 row16" >Q.8</th>
#       <td id="T_75d1e_row16_col0" class="data row16 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row17" class="row_heading level0 row17" >P.1.12</th>
#       <td id="T_75d1e_row17_col0" class="data row17 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row18" class="row_heading level0 row18" >A.2</th>
#       <td id="T_75d1e_row18_col0" class="data row18 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row19" class="row_heading level0 row19" >Ba.1.14</th>
#       <td id="T_75d1e_row19_col0" class="data row19 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row20" class="row_heading level0 row20" >B.1.111</th>
#       <td id="T_75d1e_row20_col0" class="data row20 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row21" class="row_heading level0 row21" >B.1.1.354</th>
#       <td id="T_75d1e_row21_col0" class="data row21 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row22" class="row_heading level0 row22" >B.1.1.231</th>
#       <td id="T_75d1e_row22_col0" class="data row22 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row23" class="row_heading level0 row23" >B.1.1.198</th>
#       <td id="T_75d1e_row23_col0" class="data row23 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row24" class="row_heading level0 row24" >B.1.1.194</th>
#       <td id="T_75d1e_row24_col0" class="data row24 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row25" class="row_heading level0 row25" >Ay.100</th>
#       <td id="T_75d1e_row25_col0" class="data row25 col0" >0.0057</td>
#     </tr>
#     <tr>
#       <th id="T_75d1e_level0_row26" class="row_heading level0 row26" >Unassigned</th>
#       <td id="T_75d1e_row26_col0" class="data row26 col0" >0.0057</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df
 .loc['2021/12':'2022/03']
 .groupby(['linaje'])
 .agg({'linaje':'count'})
 .rename(columns={'linaje':'Rel. Perc'})
 .apply(lambda s: s / s.sum())
 .sort_values(by='Rel. Perc', ascending=False)
 .style
 .set_caption('Tercera Ola\t(Mar-Jun 2020)')
 .background_gradient(axis=None, vmin=0, vmax=0.43, cmap='inferno')
 .format('{:.4f}')
)
# Out:
# <style type="text/css">
# #T_2da87_row0_col0 {
#   background-color: #f6fa96;
#   color: #000000;
# }
# #T_2da87_row1_col0 {
#   background-color: #a82e5f;
#   color: #f1f1f1;
# }
# #T_2da87_row2_col0, #T_2da87_row3_col0 {
#   background-color: #190c3e;
#   color: #f1f1f1;
# }
# #T_2da87_row4_col0 {
#   background-color: #140b34;
#   color: #f1f1f1;
# }
# #T_2da87_row5_col0 {
#   background-color: #0e092b;
#   color: #f1f1f1;
# }
# #T_2da87_row6_col0, #T_2da87_row7_col0 {
#   background-color: #0d0829;
#   color: #f1f1f1;
# }
# #T_2da87_row8_col0 {
#   background-color: #0b0724;
#   color: #f1f1f1;
# }
# #T_2da87_row9_col0 {
#   background-color: #050417;
#   color: #f1f1f1;
# }
# #T_2da87_row10_col0, #T_2da87_row11_col0 {
#   background-color: #030210;
#   color: #f1f1f1;
# }
# #T_2da87_row12_col0 {
#   background-color: #02020e;
#   color: #f1f1f1;
# }
# #T_2da87_row13_col0, #T_2da87_row14_col0 {
#   background-color: #02010a;
#   color: #f1f1f1;
# }
# #T_2da87_row15_col0, #T_2da87_row16_col0, #T_2da87_row17_col0 {
#   background-color: #010108;
#   color: #f1f1f1;
# }
# #T_2da87_row18_col0 {
#   background-color: #010106;
#   color: #f1f1f1;
# }
# #T_2da87_row19_col0, #T_2da87_row20_col0, #T_2da87_row21_col0, #T_2da87_row22_col0, #T_2da87_row23_col0, #T_2da87_row24_col0, #T_2da87_row25_col0, #T_2da87_row26_col0 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_2da87_row27_col0, #T_2da87_row28_col0, #T_2da87_row29_col0, #T_2da87_row30_col0, #T_2da87_row31_col0, #T_2da87_row32_col0, #T_2da87_row33_col0, #T_2da87_row34_col0, #T_2da87_row35_col0, #T_2da87_row36_col0 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2da87_">
#   <caption>Tercera Ola	(Mar-Jun 2020)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Rel. Perc</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >linaje</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2da87_level0_row0" class="row_heading level0 row0" >Ba.1.1</th>
#       <td id="T_2da87_row0_col0" class="data row0 col0" >0.4221</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row1" class="row_heading level0 row1" >Ba.1.14</th>
#       <td id="T_2da87_row1_col0" class="data row1 col0" >0.1936</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row2" class="row_heading level0 row2" >Ba.1</th>
#       <td id="T_2da87_row2_col0" class="data row2 col0" >0.0454</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row3" class="row_heading level0 row3" >Ay.100</th>
#       <td id="T_2da87_row3_col0" class="data row3 col0" >0.0454</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row4" class="row_heading level0 row4" >Ay.122</th>
#       <td id="T_2da87_row4_col0" class="data row4 col0" >0.0393</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row5" class="row_heading level0 row5" >Ba.1.15</th>
#       <td id="T_2da87_row5_col0" class="data row5 col0" >0.0333</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row6" class="row_heading level0 row6" >Ba.1.1.11</th>
#       <td id="T_2da87_row6_col0" class="data row6 col0" >0.0318</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row7" class="row_heading level0 row7" >Unassigned</th>
#       <td id="T_2da87_row7_col0" class="data row7 col0" >0.0318</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row8" class="row_heading level0 row8" >Ba.1.18</th>
#       <td id="T_2da87_row8_col0" class="data row8 col0" >0.0272</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row9" class="row_heading level0 row9" >Ba.1.1.1</th>
#       <td id="T_2da87_row9_col0" class="data row9 col0" >0.0182</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row10" class="row_heading level0 row10" >Ba.1.1.15</th>
#       <td id="T_2da87_row10_col0" class="data row10 col0" >0.0121</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row11" class="row_heading level0 row11" >Ay.25.1</th>
#       <td id="T_2da87_row11_col0" class="data row11 col0" >0.0121</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row12" class="row_heading level0 row12" >Ba.1.1.16</th>
#       <td id="T_2da87_row12_col0" class="data row12 col0" >0.0106</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row13" class="row_heading level0 row13" >Ba.1.20</th>
#       <td id="T_2da87_row13_col0" class="data row13 col0" >0.0076</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row14" class="row_heading level0 row14" >Ba.1.17</th>
#       <td id="T_2da87_row14_col0" class="data row14 col0" >0.0076</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row15" class="row_heading level0 row15" >Ay.103</th>
#       <td id="T_2da87_row15_col0" class="data row15 col0" >0.0061</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row16" class="row_heading level0 row16" >B.1</th>
#       <td id="T_2da87_row16_col0" class="data row16 col0" >0.0061</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row17" class="row_heading level0 row17" >Ba.1.19</th>
#       <td id="T_2da87_row17_col0" class="data row17 col0" >0.0061</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row18" class="row_heading level0 row18" >Ay.43</th>
#       <td id="T_2da87_row18_col0" class="data row18 col0" >0.0045</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row19" class="row_heading level0 row19" >Ay.112</th>
#       <td id="T_2da87_row19_col0" class="data row19 col0" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row20" class="row_heading level0 row20" >B.1.617.2</th>
#       <td id="T_2da87_row20_col0" class="data row20 col0" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row21" class="row_heading level0 row21" >B.1.1</th>
#       <td id="T_2da87_row21_col0" class="data row21 col0" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row22" class="row_heading level0 row22" >Ba.2.3</th>
#       <td id="T_2da87_row22_col0" class="data row22 col0" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row23" class="row_heading level0 row23" >Ba.1.1.8</th>
#       <td id="T_2da87_row23_col0" class="data row23 col0" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row24" class="row_heading level0 row24" >Ay.44</th>
#       <td id="T_2da87_row24_col0" class="data row24 col0" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row25" class="row_heading level0 row25" >Ay.20</th>
#       <td id="T_2da87_row25_col0" class="data row25 col0" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row26" class="row_heading level0 row26" >Ba.1.16</th>
#       <td id="T_2da87_row26_col0" class="data row26 col0" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row27" class="row_heading level0 row27" >Ba.1.9</th>
#       <td id="T_2da87_row27_col0" class="data row27 col0" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row28" class="row_heading level0 row28" >Ba.2.5</th>
#       <td id="T_2da87_row28_col0" class="data row28 col0" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row29" class="row_heading level0 row29" >Ba.1.1.14</th>
#       <td id="T_2da87_row29_col0" class="data row29 col0" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row30" class="row_heading level0 row30" >Ay.43.3</th>
#       <td id="T_2da87_row30_col0" class="data row30 col0" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row31" class="row_heading level0 row31" >Ba.1.1.13</th>
#       <td id="T_2da87_row31_col0" class="data row31 col0" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row32" class="row_heading level0 row32" >Ay.101</th>
#       <td id="T_2da87_row32_col0" class="data row32 col0" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row33" class="row_heading level0 row33" >B.1.621</th>
#       <td id="T_2da87_row33_col0" class="data row33 col0" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row34" class="row_heading level0 row34" >B</th>
#       <td id="T_2da87_row34_col0" class="data row34 col0" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_2da87_level0_row35" class="row_heading level0 row35" >Ay.5</th>
#       <td id="T_2da87_row35

# %% [markdown]
# ### Anomalies

# %%
# On June 5th 2020, for the column `positivas_pcr_nuevas` 
# there is a negative value
(cas_
 .loc['2020/05/06']
 ['positivas_pcr_nuevas']
)

# %%
(cas_
 .loc['2020/05/08']
 ['positivas_pcr_nuevas']
)
