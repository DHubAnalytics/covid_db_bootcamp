# %%
import pandas as pd
import numpy as np
from unidecode import unidecode
import os
import glob

# %%
df, muta = [pd.read_csv(file_) for file_ in glob.glob(os.path.join('../data/', '*'))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df, muta = [pd.read_csv(file_) for file_ in glob.glob(os.path.join('../data/', '*'))]
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %% [markdown]
# ### Missing Values

# %%
df.isna().mean() * 100
# Out:
# GISAID ID                     0.060680
# Unnamed: 1                  100.000000
# Virus name                    0.060680
# FECHA DE COLECCIÓN            0.060680
# FECHA DE SUBIDA A GISAID      0.060680
# PROVINCIA                     0.060680
# CIUDAD                        0.242718
# TIPO                          0.910194
# Genero                        0.060680
# Edad                          0.060680
# Linaje                        0.060680
# Clado                         0.060680
# Mutaciones                    0.060680
# dtype: float64

# %%
muta.isna().mean() * 100
# Out:
# 0I (Alpha, V1) (B.1.1.7)        78.181818
# 20H (Beta, V2) (B.1.351)        80.000000
# 20J (Gamma, V3) (P.1)           78.181818
# 21A (Delta) (B.1.617.2)         83.636364
# 21B (Kappa) (B.1.617.1)         89.090909
# 21K (Omicron) (BA.1)            34.545455
# 21L (Omicron) (BA.2)            43.636364
# 22A & 22B (Omicron) (BA.4&5)    38.181818
# 22C (Omicron) (BA.2.12.1)       40.000000
# 21D (Eta) (B.1.525)             83.636364
# 21F (Iota) (B.1.526)            89.090909
# 21G (Lambda) (C.37)             74.545455
# 21H (Mu) (B.1.621)              83.636364
# dtype: float64

# %% [markdown]
# ### Memory Usage

# %%
(df
 .memory_usage(deep=True)
 .pipe(lambda df_:pd.concat([df_, df.dtypes], axis=1))
 .rename(columns={0:'memory', 1:'dtype'})
)
# Out:
#                           memory    dtype
# Index                        128      NaN
# GISAID ID                 119098   object
# Unnamed: 1                 13184  float64
# Virus name                143752   object
# FECHA DE COLECCIÓN        110114   object
# FECHA DE SUBIDA A GISAID  110381   object
# PROVINCIA                 110907   object
# CIUDAD                    106642   object
# TIPO                      109197   object
# Genero                    102496   object
# Edad                      104054   object
# Linaje                    103418   object
# Clado                      97556   object
# Mutaciones                601525   object

# %% [markdown]
# ### The Data

# %%
df.sample(10).T
# Out:
#                                                                        1192  \
# GISAID ID                                                  EPI_ISL_11012600
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-2886/2022
# FECHA DE COLECCIÓN                                               2022-02-05
# FECHA DE SUBIDA A GISAID                                         2022-03-14
# PROVINCIA                                                         Pichincha
# CIUDAD                                                                QUITO
# TIPO                                                            Ambulatorio
# Genero                                                               Female
# Edad                                                                unknown
# Linaje                                                            BA.1.1.11
# Clado                                                                   GRA
# Mutaciones                (NSP5_P132H,Spike_H69del,Spike_T95I,Spike_A67V...
#
#                                                                        1485  \
# GISAID ID                                                  EPI_ISL_11579440
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-3275/2022
# FECHA DE COLECCIÓN                                               2022-01-16
# FECHA DE SUBIDA A GISAID                                         2022-03-30
# PROVINCIA                                                         Pichincha
# CIUDAD                                                                QUITO
# TIPO                                                            Ambulatorio
# Genero                                                                 Male
# Edad                                                                unknown
# Linaje                                                              BA.1.14
# Clado                                                                   GRA
# Mutaciones                (NSP5_P132H,Spike_T95I,NSP1_M85del,Spike_A67V,...
#
#                                                                        673   \
# GISAID ID                                                   EPI_ISL_3824601
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-2031/2021
# FECHA DE COLECCIÓN                                               2021-07-26
# FECHA DE SUBIDA A GISAID                                         2021-08-31
# PROVINCIA                                                         Pichincha
# CIUDAD                                                                QUITO
# TIPO                                                            Ambulatorio
# Genero                                                               Female
# Edad                                                                unknown
# Linaje                                                                  B.1
# Clado                                                                     G
# Mutaciones                (NSP6_G107del,NSP6_S106del,NSP6_F108del,Spike_...
#
#                                                                        1320  \
# GISAID ID                                                  EPI_ISL_11048445
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-3043/2022
# FECHA DE COLECCIÓN                                               2022-01-06
# FECHA DE SUBIDA A GISAID                                         2022-03-15
# PROVINCIA                                                         Pichincha
# CIUDAD                                                                QUITO
# TIPO                                                            Ambulatorio
# Genero                                                              unknown
# Edad                                                                unknown
# Linaje                                                               AY.122
# Clado                                                                     G
# Mutaciones                (N_D63G,N_R203M,NSP12_G671S,NSP3_M196I,NS3_S26...
#
#                                                                        1624  \
# GISAID ID                                                  EPI_ISL_13102251
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-3442/2022
# FECHA DE COLECCIÓN                                               2022-05-26
# FECHA DE SUBIDA A GISAID                                         2022-06-03
# PROVINCIA                                                        Pichincha
# CIUDAD                                                                Quito
# TIPO                                                            Ambulatorio
# Genero                                                               Female
# Edad                                                                unknown
# Linaje                                                                 BA.2
# Clado                                                                   GRA
# Mutaciones                (NSP5_P132H,NSP3_G489S,NSP4_T327I,Spike_S373P,...
#
#                                                                        329   \
# GISAID ID                                                   EPI_ISL_2488765
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-1485/2021
# FECHA DE COLECCIÓN                                               2021-05-31
# FECHA DE SUBIDA A GISAID                                         2021-06-11
# PROVINCIA                                                         Sucumbios
# CIUDAD                                                           NUEVA LOJA
# TIPO                                                               Hospital
# Genero                                                                 Male
# Edad                                                                     63
# Linaje                                                                  B.1
# Clado                                                                     O
# Mutaciones                (NSP6_G107del,NSP6_S106del,NSP6_F108del,NSP13_...
#
#                                                                        951   \
# GISAID ID                                                   EPI_ISL_9489205
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-2601/2022
# FECHA DE COLECCIÓN                                               2022-01-13
# FECHA DE SUBIDA A GISAID                                         2022-02-04
# PROVINCIA                                                         Imbabura
# CIUDAD                                                               IBARRA
# TIPO                                                               Hospital
# Genero                                                               Female
# Edad                                                                unknown
# Linaje                                                               AY.100
# Clado                                                                     G
# Mutaciones                (N_G215C,N_D63G,Spike_D950N,N_R203M,NSP12_G671...
#
#                                                                        463   \
# GISAID ID                                                   EPI_ISL_3132351
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-1791/2021
# FECHA DE COLECCIÓN                                               2021-06-22
# FECHA DE SUBIDA A GISAID                                         2021-07-29
# PROVINCIA                                                         Pichincha
# CIUDAD                                                                QUITO
# TIPO                                                            Ambulatorio
# Genero                                                                 Male
# Edad                                                                unknown
# Linaje                                                                B.1.1
# Clado                                                                    GR
# Mutaciones                (N_P80R,NSP3_T1303I,NSP6_G107del,NSP6_S106del,...
#
#                                                                        1144  \
# GISAID ID                                                  EPI_ISL_11012552
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-2817/2022
# FECHA DE COLECCIÓN                                               2022-01-28
# FECHA DE SUBIDA A GISAID                                         2022-03-14
# PROVINCIA                                                             Loja
# CIUDAD                                                                 LOJA
# TIPO                                                               Hospital
# Genero                                                               Female
# Edad                                                                unknown
# Linaje                                                               BA.1.1
# Clado                                                                   GRA
# Mutaciones                (NSP5_P132H,NSP12_K718N,Spike_H69del,Spike_T95...
#
#                                                                        313
# GISAID ID                                                   EPI_ISL_2361478
# Unnamed: 1                                                              NaN
# Virus name                                   hCoV-19/Ecuador/USFQ-1434/2021
# FECHA DE COLECCIÓN                                               2021-05-12
# FECHA DE SUBIDA A GISAID                                         2021-05-31
# PROVINCIA                                                         Pichincha
# CIUDAD                                                                QUITO
# TIPO                                                               Hospital
# Genero                                                                 Male
# Edad                                                                     29
# Linaje                                                              B.1.1.7
# Clado                                                                   GRY
# Mutaciones                (Spike_H69del,NS8_Q27stop,NSP3_T183I,Spike_T71...

# %%
muta.head().T
# Out:
#                                                    0        1        2  \
# 0I (Alpha, V1) (B.1.1.7)      Principales mutaciones  S:D614G      NaN
# 20H (Beta, V2) (B.1.351)                         NaN  S:D614G  S:E484K
# 20J (Gamma, V3) (P.1)                            NaN  S:D614G  S:E484K
# 21A (Delta) (B.1.617.2)                          NaN  S:D614G      NaN
# 21B (Kappa) (B.1.617.1)                          NaN  S:D614G  S:E484Q
# 21K (Omicron) (BA.1)                             NaN  S:D614G  S:E484A
# 21L (Omicron) (BA.2)                             NaN  S:D614G  S:E484A
# 22A & 22B (Omicron) (BA.4&5)                     NaN  S:D614G  S:E484A
# 22C (Omicron) (BA.2.12.1)                        NaN  S:D614G  S:E484A
# 21D (Eta) (B.1.525)                              NaN  S:D614G  S:E484K
# 21F (Iota) (B.1.526)                             NaN  S:D614G  S:E484K
# 21G (Lambda) (C.37)                              NaN  S:D614G      NaN
# 21H (Mu) (B.1.621)                               NaN  S:D614G  S:E484K
#
#                                     3        4
# 0I (Alpha, V1) (B.1.1.7)      S:P681H  S:N501Y
# 20H (Beta, V2) (B.1.351)          NaN  S:N501Y
# 20J (Gamma, V3) (P.1)             NaN  S:N501Y
# 21A (Delta) (B.1.617.2)       S:P681R      NaN
# 21B (Kappa) (B.1.617.1)       S:P681R      NaN
# 21K (Omicron) (BA.1)          S:P681H  S:N501Y
# 21L (Omicron) (BA.2)          S:P681H  S:N501Y
# 22A & 22B (Omicron) (BA.4&5)  S:P681H  S:N501Y
# 22C (Omicron) (BA.2.12.1)     S:P681H  S:N501Y
# 21D (Eta) (B.1.525)               NaN      NaN
# 21F (Iota) (B.1.526)              NaN      NaN
# 21G (Lambda) (C.37)               NaN      NaN
# 21H (Mu) (B.1.621)            S:P681H  S:N501Y

# %% [markdown]
# ### Numerical Types

# %% [markdown]
# ### Non-Numeric Types

# %% [markdown]
# ### Datetimes

# %% [markdown]
# ### Tweak pd.DataFrames

# %%
def check_memory(df):
    print(df.memory_usage(deep=True).sum() / 1000000)
    return df

def get_shape(df):
    print(df.shape)
    return df

(df
 .drop(columns=['Unnamed: 1', 'FECHA DE SUBIDA A GISAID', 'GISAID ID'])
 .applymap(lambda tx: unidecode(tx.lower()) if isinstance(tx, str) else tx)
 .rename(columns=lambda c: c.replace(' ', '_').lower())
 .assign(virus_name = lambda df_: (df_
                                   .virus_name
                                   .str
                                   .split('/', expand=True)
                                   .loc[:, 2]),
         linaje1 = lambda df_: df_.linaje.str.split('.')
        )
 # .sample(5)
)
# Out:
#          virus_name fecha_de_colección    provincia    ciudad         tipo  \
# 0            hee-01         2020-03-09    pichincha     quito     hospital
# 1     hgsq-usfq-018         2020-03-30    pichincha     quito     hospital
# 2     hgsq-usfq-007         2020-03-30    pichincha     quito     hospital
# 3     hgsq-usfq-010         2020-03-30    pichincha     quito     hospital
# 4          usfq-020         2020-04-17    los rios   babahoyo     hospital
# ...             ...                ...          ...       ...          ...
# 1643      usfq-3477         2022-05-27   pichincha      quito  ambulatorio
# 1644      usfq-3479         2022-05-28   pichincha      quito  ambulatorio
# 1645      usfq-3482         2022-05-29   pichincha      quito  ambulatorio
# 1646      usfq-3483         2022-05-25   pichincha      quito  ambulatorio
# 1647      usfq-3484         2022-05-30   pichincha      quito  ambulatorio
#
#       genero edad  linaje clado  \
# 0       male   57    b.55     l
# 1       male   27   b.1.1    gr
# 2       male   40  b.1.14     o
# 3       male   39  b.1.14     o
# 4     female   50  b.1.67     g
# ...      ...  ...     ...   ...
# 1643    male   42    ba.2   gra
# 1644    male   54    ba.2   gra
# 1645    male    5    ba.2   gra
# 1646    male   34    ba.2   gra
# 1647  female   67  ba.2.9   gra
#
#                                              mutaciones     linaje1
# 0                                          spike e1207v     [b, 55]
# 1     (n_r203k,n_g204r,nsp12_p323l,nsp3_l431f,spike_...   [b, 1, 1]
# 2     (nsp15_s293t,ns3_q38p,ns3_v163t,ns3_r122e,ns3_...  [b, 1, 14]
# 3     (nsp15_s293t,ns3_q38p,ns3_v163t,ns3_r122e,ns3_...  [b, 1, 14]
# 4                             (nsp12_p323l,spike_d614g)  [b, 1, 67]
# ...                                                 ...         ...
# 1643  (nsp5_p132h,nsp3_g489s,nsp4_t327i,spike_s373p,...     [ba, 2]
# 1644  (nsp5_p132h,nsp3_g489s,spike_l24del,nsp4_t327i...     [ba, 2]
# 1645  (nsp5_p132h,nsp3_g489s,nsp4_t327i,spike_s373p,...     [ba, 2]
# 1646  (nsp5_p132h,spike_s371f,nsp3_g489s,nsp13_r392c...     [ba, 2]
# 1647  (nsp5_p132h,nsp3_g489s,spike_l24del,nsp4_t327i...  [ba, 2, 9]
#
# [1648 rows x 11 columns]

# %%
(df
 .drop(columns=['Unnamed: 1', 'FECHA DE SUBIDA A GISAID', 'GISAID ID'])
 .applymap(lambda tx: unidecode(tx.lower()) if isinstance(tx, str) else tx)
 .rename(columns=lambda c: c.replace(' ', '_').lower())
 .virus_name.str.split('/', expand=True)
 .loc[:, 2]
 # .assign()
 # .sample(5)
)
# Out:
# 0              hee-01
# 1       hgsq-usfq-018
# 2       hgsq-usfq-007
# 3       hgsq-usfq-010
# 4            usfq-020
#             ...
# 1643        usfq-3477
# 1644        usfq-3479
# 1645        usfq-3482
# 1646        usfq-3483
# 1647        usfq-3484
# Name: 2, Length: 1648, dtype: object

# %% [markdown]
# ### Anomalies

# %% [markdown]
# #### Cleanup Round Brainstorm
# - Drop Unnamed: 1 ; FECHA DE SUBIDA A GISAID ; GISAID ID
# - Split `Virus name` and remove first two elements
# - FECHA DE COLECCION apply pd.to_datetime()
# - rewrite columns names to make them valid keywords (lowercase and underscore instead of whitespace)
# - decode text data and transform to lowercase
# - Edad ; Genero must contain np.nan instead of unknown
# -
